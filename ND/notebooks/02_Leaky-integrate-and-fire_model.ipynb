# %% [markdown]
# # 2. Leaky-integrate-and-fire model

# %%
# %matplotlib inline
import brian2 as b2
import matplotlib.pyplot as plt
import numpy as np
from neurodynex.leaky_integrate_and_fire import LIF
from neurodynex.tools import input_factory, plot_tools


LIF.getting_started()
LIF.print_default_parameters()
# Out:
# WARNING    /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#
#  [py.warnings]
# nr of spikes: 0
# WARNING    /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#
#  [py.warnings]
# nr of spikes: 5
# Resting potential: -70. mV
# Reset voltage: -65. mV
# Firing threshold: -50. mV
# Membrane resistance: 10. Mohm
# Membrane time-scale: 8. ms
# Absolute refractory period: 2. ms
